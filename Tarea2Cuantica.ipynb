# %%
import numpy as np
import math as m
import matplotlib.pyplot as plt

def Cn(n):
    return -m.sqrt(60)*(m.pi*n*m.sin(m.pi*n)+2*m.cos(m.pi*n)-2)/(m.pi**3*n**3)

datos = []

A = m.sqrt(30)
a = 1

for x in np.arange(0, a, 0.01):
    suma = 0
    for n in range(1, 1000):
        suma += Cn(n)*m.sin(n*m.pi*x/a)
    datos.append(suma)

datos = np.array(datos)
rango = np.arange(0, a, 0.01)

print(datos)

plt.plot(rango, datos)
plt.show()
# Out:
# [0.         0.03834252 0.07591047 0.11270381 0.14872256 0.18396671
#  0.21843626 0.25213121 0.28505157 0.31719733 0.3485685  0.37916507
#  0.40898704 0.43803442 0.46630719 0.49380538 0.52052896 0.54647795
#  0.57165234 0.59605214 0.61967733 0.64252794 0.66460394 0.68590535
#  0.70643216 0.72618438 0.745162   0.76336502 0.78079344 0.79744727
#  0.8133265  0.82843114 0.84276118 0.85631662 0.86909746 0.88110371
#  0.89233536 0.90279242 0.91247488 0.92138274 0.929516   0.93687467
#  0.94345874 0.94926822 0.9543031  0.95856338 0.96204906 0.96476015
#  0.96669664 0.96785854 0.96824584 0.96785854 0.96669664 0.96476015
#  0.96204906 0.95856338 0.9543031  0.94926822 0.94345874 0.93687467
#  0.929516   0.92138274 0.91247488 0.90279242 0.89233536 0.88110371
#  0.86909746 0.85631662 0.84276118 0.82843114 0.8133265  0.79744727
#  0.78079344 0.76336502 0.745162   0.72618438 0.70643216 0.68590535
#  0.66460394 0.64252794 0.61967733 0.59605214 0.57165234 0.54647795
#  0.52052896 0.49380538 0.46630719 0.43803442 0.40898704 0.37916507
#  0.3485685  0.31719733 0.28505157 0.25213121 0.21843626 0.18396671
#  0.14872256 0.11270381 0.07591047 0.03834252]
